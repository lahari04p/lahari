# %% [markdown]
# <a href="https://colab.research.google.com/github/lahari04p/lahari/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols



 #Read the dataset into a DataFrame
df = pd.read_csv("/content/kc_house_data.csv")

 #Display the first few rows of the DataFrame
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
fig=plt.figure(figsize=(12, 6))
sqft = fig.add_subplot(121)
cost = fig.add_subplot(122)
sqft.hist(df.sqft_living, bins=80)
sqft.set_xlabel('Ft^2')
sqft.set_title("histogrsm of house square footage")
cost.hist(df.price,bins=80)
cost.set_xlabel('price ($)')
cost.set_title("histogram of housing prices")
plt.show()

# %%
m = ols('price ~ sqft_living', df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.100e+04
# Date:                Wed, 06 Mar 2024   Prob (F-statistic):               0.00
# Time:                        05:54:56   Log-Likelihood:            -3.0027e+05
# No. Observations:               21613   AIC:                         6.005e+05
# Df Residuals:                   21611   BIC:                         6.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.358e+04   4402.690     -9.899      0.000   -5.22e+04    -3.5e+04
# ...

# %%
sns.jointplot(x="sqft_living", y="price", data=df, kind='reg', height=5)
plt.show()
